# %% [markdown]
# <a href="https://colab.research.google.com/github/vaira86/ml_colab_test/blob/main/git_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Colab + GitHub funzionano!")
# Out:
# Colab + GitHub funzionano!
